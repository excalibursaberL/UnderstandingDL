# %% [markdown]
# 生成数据集

# %%
import numpy as np
# %matplotlib inline
import torch
from torch import nn
from d2l import torch as d2l
import numpy as np

n_train, n_test, num_inputs, batch_size = 20, 100, 200, 5
true_w, true_b = torch.ones((num_inputs, 1)) * 0.01, 0.05
train_data = d2l.synthetic_data(true_w, true_b, n_train)
train_iter = d2l.load_array(train_data, batch_size)
test_data = d2l.synthetic_data(true_w, true_b, n_test)
test_iter = d2l.load_array(test_data, batch_size, is_train=False)

# %% [markdown]
# 初始化模型参数

# %%
def init_params():
    w = torch.normal(0, 1, size=(num_inputs, 1), requires_grad=True)
    b = torch.zeros(1, requires_grad=True)
    return [w, b]

# %% [markdown]
# 定义 L2 范数惩罚

# %%
def l2_penalty(w):
    return torch.sum(w.pow(2)) / 2

# %% [markdown]
# 训练

# %%
def train(lambd):
    w, b = init_params()
    net, loss = lambda X: d2l.linreg(X, w, b), d2l.squared_loss
    num_epochs, lr = 100, 0.003
    animator = d2l.Animator(xlabel='epochs', ylabel='loss', yscale='log',
                            xlim=[5, num_epochs], legend=['train', 'test'])
    for epoch in range(num_epochs):
        for X, y in train_iter:
            l = loss(net(X), y) + lambd * l2_penalty(w)
            l.sum().backward()
            d2l.sgd([w, b], lr, batch_size)
        if (epoch + 1) % 5 ==0:
            animator.add(epoch + 1, (d2l.evaluate_loss(net, train_iter, loss),
                                     d2l.evaluate_loss(net, test_iter, loss)))
    return torch.norm(w).data

# %% [markdown]
# 训练

# %%
norm_value=train(lambd=0)
norm_value

# %%
print(norm_value)
# Out:
# tensor(12.4806)

# %% [markdown]
# 使用权重衰减

# %%
norm_value=train(lambd=3)
norm_value

# %%
print(norm_value)
# Out:
# tensor(0.3655)

# %% [markdown]
# 简洁实现

# %%
def train_concise(wd):
    net = nn.Sequential(nn.Linear(num_inputs, 1))
    for param in net.parameters():
        param.data.normal_()
    loss = nn.MSELoss(reduction='none')
    num_epochs, lr = 100, 0.003
    # 偏置参数没有衰减
    trainer = torch.optim.SGD([
        {"params":net[0].weight,'weight_decay': wd},
        {"params":net[0].bias}], lr=lr)
    animator = d2l.Animator(xlabel='epochs', ylabel='loss', yscale='log',
                            xlim=[5, num_epochs], legend=['train', 'test'])
    for epoch in range(num_epochs):
        for X, y in train_iter:
            trainer.zero_grad()
            l = loss(net(X), y)
            l.mean().backward()
            trainer.step()
        if (epoch + 1) % 5 == 0:
            animator.add(epoch + 1,
                         (d2l.evaluate_loss(net, train_iter, loss),
                          d2l.evaluate_loss(net, test_iter, loss)))
    return net[0].weight.norm().item()

# %% [markdown]
# 简洁训练

# %%
concise_norm = train_concise(0)
concise_norm

# %%
print(concise_norm)
# Out:
# 14.249305725097656

# %% [markdown]
# 调整 lambda

# %%
concise_norm = train_concise(3)
concise_norm

# %%
print(concise_norm)
# Out:
# 0.4233556389808655

# %% [markdown]
# 练习 4.5.1 在本节的估计问题中使用 λ 的值进行实验。绘制训练和测试精度关于 λ 的函数图。可以观察到什么？

# %%
def train_wd(wd_list, train_iter, test_iter):
    norm_value_list = []
    net = nn.Sequential(nn.Linear(num_inputs, 1))
    loss = nn.MSELoss(reduction='none')
    num_epochs, lr = 100, 0.003
    animator = d2l.Animator(xlabel='$\lambda$', ylabel='loss', yscale='log',
                            xlim=[wd_list[0], wd_list[-1]], legend=['train', 'test'])
    for param in net.parameters():
        param.data.normal_()

    for wd in wd_list:
        for i in [0]:
            trainer = torch.optim.SGD([
                {"params":net[i].weight,'weight_decay': wd},
                {"params":net[i].bias}], lr=lr)

        for epoch in range(num_epochs):
            trainer.zero_grad()
            for X, y in train_iter:
                trainer.zero_grad()
                l = loss(net(X), y)
                l.mean().backward()
                trainer.step()

        animator.add(wd,(d2l.evaluate_loss(net, train_iter, loss),
                              d2l.evaluate_loss(net, test_iter, loss)))

        norm_value_list.append(net[0].weight.norm().item())

    return norm_value_list

norm_value_list = train_wd(np.linspace(0, 100, 150), train_iter, test_iter)
norm_value_list

# %%
from fractions import Fraction

# 在你的循环中使用 Fraction
for i in range(len(norm_value_list)):
    lambda_fraction = Fraction(2*(i+1), 3)
    print(f"lambda 为 {lambda_fraction} 时的 L2 范数为: {norm_value_list[i]}")
# Out:
# lambda 为 2/3 时的 L2 范数为: 13.921030044555664
# lambda 为 4/3 时的 L2 范数为: 6.216705322265625
# lambda 为 2 时的 L2 范数为: 1.2383248805999756
# lambda 为 8/3 时的 L2 范数为: 0.11541284620761871
# lambda 为 10/3 时的 L2 范数为: 0.03242160379886627
# lambda 为 4 时的 L2 范数为: 0.029294610023498535
# lambda 为 14/3 时的 L2 范数为: 0.027327604591846466
# lambda 为 16/3 时的 L2 范数为: 0.026021119207143784
# lambda 为 6 时的 L2 范数为: 0.025221697986125946
# lambda 为 20/3 时的 L2 范数为: 0.024478208273649216
# lambda 为 22/3 时的 L2 范数为: 0.023742329329252243
# lambda 为 8 时的 L2 范数为: 0.02313871681690216
# lambda 为 26/3 时的 L2 范数为: 0.022566474974155426
# lambda 为 28/3 时的 L2 范数为: 0.02204594761133194
# lambda 为 10 时的 L2 范数为: 0.021527305245399475
# lambda 为 32/3 时的 L2 范数为: 0.020993202924728394
# lambda 为 34/3 时的 L2 范数为: 0.020675601437687874
# lambda 为 12 时的 L2 范数为: 0.020090682432055473
# lambda 为 38/3 时的 L2 范数为: 0.019803963601589203
# lambda 为 40/3 时的 L2 范数为: 0.019523296505212784
# lambda 为 14 时的 L2 范数为: 0.019152628257870674
# lambda 为 44/3 时的 L2 范数为: 0.01857556588947773
# lambda 为 46/3 时的 L2 范数为: 0.018253805115818977
# lambda 为 16 时的 L2 范数为: 0.01798112504184246
# lambda 为 50/3 时的 L2 范数为: 0.017395421862602234
# lambda 为 52/3 时的 L2 范数为: 0.01740911416709423
# lambda 为 18 时的 L2 范数为: 0.016909470781683922
# lambda 为 56/3 时的 L2 范数为: 0.016734983772039413
# lambda 为 58/3 时的 L2 范数为: 0.016342872753739357
# lambda 为 20 时的 L2 范数为: 0.016340984031558037
# lambda 为 62/3 时的 L2 范数为: 0.01610814407467842
# lambda 为 64/3 时的 L2 范数为: 0.015923453494906425
# lambda 为 22 时的 L2 范数为: 0.01541634276509285
# lambda 为 68/3 时的 L2 范数为: 0.015402112156152725
# lambda 为 70/3 时的 L2 范数为: 0.014660329557955265
# lambda 为 24 时的 L2 范数为: 0.014761300757527351
# lambda 为 74/3 时的 L2 范数为: 0.014729180373251438
# lambda 为 76/3 时的 L2 范数为: 0.014369169250130653
# lambda 为 26 时的 L2 范数为: 0.014245826750993729
# lambda 为 80/3 时的 L2 范数为: 0.014466057531535625
# lambda 为 82/3 时的 L2 范数为: 0.013997401110827923
# lambda 为 28 时的 L2 范数为: 0.013512754812836647
# lambda 为 86/3 时的 L2 范数为: 0.013409637846052647
# lambda 为 88/3 时的 L2 范数为: 0.013412083499133587
# lambda 为 30 时的 L2 范数为: 0.01346920058131218
# lambda 为 92/3 时的 L2 范数为: 0.01270075049251318
# lambda 为 94/3 时的 L2 范数为: 0.012913073413074017
# lambda 为 32 时的 L2 范数为: 0.012527531944215298
# lambda 为 98/3 时的 L2 范数为: 0.0126076964661479
# lambda 为 100/3 时的 L2 范数为: 0.012265286408364773
# lambda 为 34 时的 L2 范数为: 0.012460565194487572
# lambda 为 104/3 时的 L2 范数为: 0.012007022276520729
# lambda 为 106/3 时的 L2 范数为: 0.01167523954063654
# lambda 为 36 时的 L2 范数为: 0.012071498669683933
# lambda 为 110/3 时的 L2 范数为: 0.011716753244400024
# lambda 为 112/3 时的 L2 范数为: 0.011522109620273113
# lambda 为 38 时的 L2 范数为: 0.011207741685211658
# lambda 为 116/3 时的 L2 范数为: 0.011709975078701973
# lambda 为 118/3 时的 L2 范数为: 0.011303125880658627
# lambda 为 40 时的 L2 范数为: 0.011157948523759842
# lambda 为 122/3 时的 L2 范数为: 0.01051434688270092
# lambda 为 124/3 时的 L2 范数为: 0.010769297368824482
# lambda 为 42 时的 L2 范数为: 0.010672089643776417
# lambda 为 128/3 时的 L2 范数为: 0.0102267200127244
# lambda 为 130/3 时的 L2 范数为: 0.010289612226188183
# lambda 为 44 时的 L2 范数为: 0.010460513643920422
# lambda 为 134/3 时的 L2 范数为: 0.009972170926630497
# lambda 为 136/3 时的 L2 范数为: 0.009691759943962097
# lambda 为 46 时的 L2 范数为: 0.010168936103582382
# lambda 为 140/3 时的 L2 范数为: 0.010436192154884338
# lambda 为 142/3 时的 L2 范数为: 0.010049845091998577
# lambda 为 48 时的 L2 范数为: 0.010301913134753704
# lambda 为 146/3 时的 L2 范数为: 0.00919286534190178
# lambda 为 148/3 时的 L2 范数为: 0.010178188793361187
# lambda 为 50 时的 L2 范数为: 0.009769764728844166
# lambda 为 152/3 时的 L2 范数为: 0.009807411581277847
# lambda 为 154/3 时的 L2 范数为: 0.0091378353536129
# lambda 为 52 时的 L2 范数为: 0.009459433145821095
# lambda 为 158/3 时的 L2 范数为: 0.009156816639006138
# lambda 为 160/3 时的 L2 范数为: 0.009162669070065022
# lambda 为 54 时的 L2 范数为: 0.009754865430295467
# lambda 为 164/3 时的 L2 范数为: 0.008977098390460014
# lambda 为 166/3 时的 L2 范数为: 0.009084994904696941
# lambda 为 56 时的 L2 范数为: 0.009442719630897045
# lambda 为 170/3 时的 L2 范数为: 0.009367764927446842
# lambda 为 172/3 时的 L2 范数为: 0.009302140213549137
# lambda 为 58 时的 L2 范数为: 0.007948056794703007
# lambda 为 176/3 时的 L2 范数为: 0.00804668664932251
# lambda 为 178/3 时的 L2 范数为: 0.008576084859669209
# lambda 为 60 时的 L2 范数为: 0.008384809829294682
# lambda 为 182/3 时的 L2 范数为: 0.008037586696445942
# lambda 为 184/3 时的 L2 范数为: 0.008190016262233257
# lambda 为 62 时的 L2 范数为: 0.009320974349975586
# lambda 为 188/3 时的 L2 范数为: 0.008661587722599506
# lambda 为 190/3 时的 L2 范数为: 0.007968639023602009
# lambda 为 64 时的 L2 范数为: 0.008064096793532372
# lambda 为 194/3 时的 L2 范数为: 0.007836521603167057
# lambda 为 196/3 时的 L2 范数为: 0.008023055270314217
# lambda 为 66 时的 L2 范数为: 0.00800616666674614
# lambda 为 200/3 时的 L2 范数为: 0.007499700412154198
# lambda 为 202/3 时的 L2 范数为: 0.008412343449890614
# lambda 为 68 时的 L2 范数为: 0.008407697081565857
# lambda 为 206/3 时的 L2 范数为: 0.00789919774979353
# lambda 为 208/3 时的 L2 范数为: 0.007564275525510311
# lambda 为 70 时的 L2 范数为: 0.00870870053768158
# lambda 为 212/3 时的 L2 范数为: 0.007388979662209749
# lambda 为 214/3 时的 L2 范数为: 0.007883068174123764
# lambda 为 72 时的 L2 范数为: 0.008686198852956295
# lambda 为 218/3 时的 L2 范数为: 0.007428366225212812
# lambda 为 220/3 时的 L2 范数为: 0.00770894018933177
# lambda 为 74 时的 L2 范数为: 0.006908021867275238
# lambda 为 224/3 时的 L2 范数为: 0.007918204180896282
# lambda 为 226/3 时的 L2 范数为: 0.00743080722168088
# lambda 为 76 时的 L2 范数为: 0.007093916647136211
# lambda 为 230/3 时的 L2 范数为: 0.007160195615142584
# lambda 为 232/3 时的 L2 范数为: 0.006612830795347691
# lambda 为 78 时的 L2 范数为: 0.0067130886018276215
# lambda 为 236/3 时的 L2 范数为: 0.007948496378958225
# lambda 为 238/3 时的 L2 范数为: 0.007561362814158201
# lambda 为 80 时的 L2 范数为: 0.005849698558449745
# lambda 为 242/3 时的 L2 范数为: 0.00680572772398591
# lambda 为 244/3 时的 L2 范数为: 0.007077692076563835
# lambda 为 82 时的 L2 范数为: 0.007695493288338184
# lambda 为 248/3 时的 L2 范数为: 0.005770105868577957
# lambda 为 250/3 时的 L2 范数为: 0.006598396226763725
# lambda 为 84 时的 L2 范数为: 0.006227592006325722
# lambda 为 254/3 时的 L2 范数为: 0.006047260947525501
# lambda 为 256/3 时的 L2 范数为: 0.006597674917429686
# lambda 为 86 时的 L2 范数为: 0.007050439715385437
# lambda 为 260/3 时的 L2 范数为: 0.007554235868155956
# lambda 为 262/3 时的 L2 范数为: 0.005837068893015385
# lambda 为 88 时的 L2 范数为: 0.006181883160024881
# lambda 为 266/3 时的 L2 范数为: 0.006708610337227583
# lambda 为 268/3 时的 L2 范数为: 0.005735478363931179
# lambda 为 90 时的 L2 范数为: 0.006462824996560812
# lambda 为 272/3 时的 L2 范数为: 0.00598700949922204
# lambda 为 274/3 时的 L2 范数为: 0.006995547097176313
# lambda 为 92 时的 L2 范数为: 0.006832526531070471
# lambda 为 278/3 时的 L2 范数为: 0.006185536272823811
# lambda 为 280/3 时的 L2 范数为: 0.006001726258546114
# lambda 为 94 时的 L2 范数为: 0.006497760768979788
# lambda 为 284/3 时的 L2 范数为: 0.006062734872102737
# lambda 为 286/3 时的 L2 范数为: 0.006652636919170618
# lambda 为 96 时的 L2 范数为: 0.005767292808741331
# lambda 为 290/3 时的 L2 范数为: 0.0063384217210114
# lambda 为 292/3 时的 L2 范数为: 0.006706063635647297
# lambda 为 98 时的 L2 范数为: 0.006341159343719482
# lambda 为 296/3 时的 L2 范数为: 0.006080475635826588
# lambda 为 298/3 时的 L2 范数为: 0.006284384522587061
# lambda 为 100 时的 L2 范数为: 0.006119148805737495
